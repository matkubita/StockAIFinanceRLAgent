# %%
import pandas as pd
from stable_baselines3.common.logger import configure

from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.config import INDICATORS, TRAINED_MODEL_DIR, RESULTS_DIR
from finrl.main import check_and_make_directories
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv

check_and_make_directories([TRAINED_MODEL_DIR])

# %%
train = pd.read_csv('data/train_data.csv')

# %%
train.head()
# Out:
#          date    tic       close        high         low        open  \
# 0  2018-01-02   AAPL   40.341892   40.351262   39.639317   39.850091
# 1  2018-01-02   AMZN   59.450500   59.500000   58.525501   58.599998
# 2  2018-01-02  BRK-B  197.220001  198.869995  195.960007  198.869995
# 3  2018-01-02  GOOGL   53.258095   53.395556   52.256167   52.256167
# 4  2018-01-02    JPM   86.730354   86.786594   85.814444   86.473257
#
#         volume  day  macd    boll_ub    boll_lb  rsi_30     cci_30  dx_30  \
# 0  102223600.0  1.0   0.0  40.348316  40.328442     0.0  66.666667  100.0
# 1   53890000.0  1.0   0.0  40.348316  40.328442     0.0  66.666667  100.0
# 2    4113000.0  1.0   0.0  40.348316  40.328442     0.0  66.666667  100.0
# 3   31766000.0  1.0   0.0  40.348316  40.328442     0.0  66.666667  100.0
# 4   13578800.0  1.0   0.0  40.348316  40.328442     0.0  66.666667  100.0
#
#    close_30_sma  close_60_sma   vix  turbulence
# 0     40.341892     40.341892  9.77         0.0
# 1     59.450500     59.450500  9.77         0.0
# 2    197.220001    197.220001  9.77         0.0
# 3     53.258095     53.258095  9.77         0.0
# 4     86.730354     86.730354  9.77         0.0

# %%
if "Unnamed: 0" in train.columns:
    train = train.drop(columns=["Unnamed: 0"])

train = train.sort_values(['date', 'tic']).reset_index(drop=True)

train.index = train['date'].factorize()[0]

# %%
train.shape
# Out:
# (12590, 18)

# %%
train.head()
# Out:
#          date    tic       close        high         low        open  \
# 0  2018-01-02   AAPL   40.341892   40.351262   39.639317   39.850091
# 0  2018-01-02   AMZN   59.450500   59.500000   58.525501   58.599998
# 0  2018-01-02  BRK-B  197.220001  198.869995  195.960007  198.869995
# 0  2018-01-02  GOOGL   53.258095   53.395556   52.256167   52.256167
# 0  2018-01-02    JPM   86.730354   86.786594   85.814444   86.473257
#
#         volume  day  macd    boll_ub    boll_lb  rsi_30     cci_30  dx_30  \
# 0  102223600.0  1.0   0.0  40.348316  40.328442     0.0  66.666667  100.0
# 0   53890000.0  1.0   0.0  40.348316  40.328442     0.0  66.666667  100.0
# 0    4113000.0  1.0   0.0  40.348316  40.328442     0.0  66.666667  100.0
# 0   31766000.0  1.0   0.0  40.348316  40.328442     0.0  66.666667  100.0
# 0   13578800.0  1.0   0.0  40.348316  40.328442     0.0  66.666667  100.0
#
#    close_30_sma  close_60_sma   vix  turbulence
# 0     40.341892     40.341892  9.77         0.0
# 0     59.450500     59.450500  9.77         0.0
# 0    197.220001    197.220001  9.77         0.0
# 0     53.258095     53.258095  9.77         0.0
# 0     86.730354     86.730354  9.77         0.0

# %%
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 10, State Space: 101

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}

# %%
e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)


# set up logger
tmp_path = RESULTS_DIR + '/ppo'
new_logger_ppo = configure(tmp_path, ["stdout", "csv", "tensorboard"])
# Set new logger
model_ppo.set_logger(new_logger_ppo)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device
# Logging to results/ppo

# %%
model_ppo.learn(total_timesteps=50000, tb_log_name='ppo')
trained_ppo = model_ppo
# Out:
# ---------------------------------
# | time/              |          |
# |    fps             | 389      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 2048     |
# | train/             |          |
# |    learning_rate   | 0.00025  |
# ---------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 369         |
# |    iterations           | 2           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.005943491 |
# |    clip_fraction        | 0.0487      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.2       |
# |    explained_variance   | -0.0096     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 41.5        |
# |    n_updates            | 28          |
# |    policy_gradient_loss | -0.00627    |
# |    std                  | 1           |
# |    value_loss           | 81.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 355         |
# |    iterations           | 3           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.004480648 |
# |    clip_fraction        | 0.0217      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.2       |
# |    explained_variance   | -0.00318    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 67.1        |
# |    n_updates            | 38          |
# |    policy_gradient_loss | -0.00178    |
# |    std                  | 1.01        |
# |    value_loss           | 118         |
# -----------------------------------------
# day: 1258, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 1401579.62
# total_reward: 401579.62
# total_cost: 86907.07
# total_trades: 12039
# Sharpe: 0.384
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 351         |
# |    iterations           | 4           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.004870058 |
# |    clip_fraction        | 0.041       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.3       |
# |    explained_variance   | -0.00118    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 49.1        |
# |    n_updates            | 48          |
# |    policy_gradient_loss | -0.00462    |
# |    std                  | 1.01        |
# |    value_loss           | 85.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 346         |
# |    iterations           | 5           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007828427 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.3       |
# |    explained_variance   | 0.0235      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 36.8        |
# |    n_updates            | 58          |
# |    policy_gradient_loss | -0.00775    |
# |    std                  | 1.01        |
# |    value_loss           | 72.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 347         |
# |    iterations           | 6           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008273879 |
# |    clip_fraction        | 0.0859      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.3       |
# |    explained_variance   | 0.0296      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 44.6        |
# |    n_updates            | 68          |
# |    policy_gradient_loss | -0.0036     |
# |    std                  | 1.01        |
# |    value_loss           | 139         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 342         |
# |    iterations           | 7           |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008145761 |
# |    clip_fraction        | 0.0447      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.3       |
# |    explained_variance   | 0.049       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 33          |
# |    n_updates            | 78          |
# |    policy_gradient_loss | -0.00723    |
# |    std                  | 1.01        |
# |    value_loss           | 60.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 330         |
# |    iterations           | 8           |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009777553 |
# |    clip_fraction        | 0.0975      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.3       |
# |    explained_variance   | 0.024       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 79.5        |
# |    n_updates            | 88          |
# |    policy_gradient_loss | -0.0092     |
# |    std                  | 1.01        |
# |    value_loss           | 164         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 320        |
# |    iterations           | 9          |
# |    time_elapsed         | 57         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.00686946 |
# |    clip_fraction        | 0.0659     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -14.3      |
# |    explained_variance   | 0.0279     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 156        |
# |    n_updates            | 98         |
# |    policy_gradient_loss | -0.00593   |
# |    std                  | 1.01       |
# |    value_loss           | 306        |
# ----------------------------------------
# day: 1258, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 2298744.25
# total_reward: 1298744.25
# total_cost: 83444.62
# total_trades: 11944
# Sharpe: 0.645
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 10          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.006684919 |
# |    clip_fraction        | 0.0298      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.3       |
# |    explained_variance   | 0.00547     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 131         |
# |    n_updates            | 108         |
# |    policy_gradient_loss | -0.00288    |
# |    std                  | 1.02        |
# |    value_loss           | 238         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 297        |
# |    iterations           | 11         |
# |    time_elapsed         | 75         |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.00794666 |
# |    clip_fraction        | 0.0421     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -14.3      |
# |    explained_variance   | 0.0189     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 151        |
# |    n_updates            | 118        |
# |    policy_gradient_loss | -0.00518   |
# |    std                  | 1.02       |
# |    value_loss           | 394        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 293         |
# |    iterations           | 12          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.006786662 |
# |    clip_fraction        | 0.047       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.3       |
# |    explained_variance   | 0.0107      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 105         |
# |    n_updates            | 128         |
# |    policy_gradient_loss | -0.00591    |
# |    std                  | 1.02        |
# |    value_loss           | 311         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 293          |
# |    iterations           | 13           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0075339014 |
# |    clip_fraction        | 0.0344       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -14.4        |
# |    explained_variance   | 0.0301       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 207          |
# |    n_updates            | 138          |
# |    policy_gradient_loss | -0.00748     |
# |    std                  | 1.02         |
# |    value_loss           | 383          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 14          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008018098 |
# |    clip_fraction        | 0.0471      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.4       |
# |    explained_variance   | 0.0405      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 158         |
# |    n_updates            | 148         |
# |    policy_gradient_loss | -0.00748    |
# |    std                  | 1.02        |
# |    value_loss           | 307         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 293         |
# |    iterations           | 15          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.008159714 |
# |    clip_fraction        | 0.0513      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.4       |
# |    explained_variance   | 0.0446      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 136         |
# |    n_updates            | 158         |
# |    policy_gradient_loss | -0.00493    |
# |    std                  | 1.02        |
# |    value_loss           | 226         |
# -----------------------------------------
# day: 1258, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 1415438.59
# total_reward: 415438.59
# total_cost: 84701.95
# total_trades: 11775
# Sharpe: 0.384
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 293         |
# |    iterations           | 16          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.007119159 |
# |    clip_fraction        | 0.0642      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.4       |
# |    explained_variance   | 0.0285      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 93.6        |
# |    n_updates            | 168         |
# |    policy_gradient_loss | -0.00774    |
# |    std                  | 1.02        |
# |    value_loss           | 181         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 17          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.014058294 |
# |    clip_fraction        | 0.0661      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.4       |
# |    explained_variance   | 0.0511      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 116         |
# |    n_updates            | 178         |
# |    policy_gradient_loss | -0.00919    |
# |    std                  | 1.02        |
# |    value_loss           | 175         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 292          |
# |    iterations           | 18           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0142840445 |
# |    clip_fraction        | 0.116        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -14.4        |
# |    explained_variance   | 0.0766       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 20.6         |
# |    n_updates            | 188          |
# |    policy_gradient_loss | -0.00822     |
# |    std                  | 1.02         |
# |    value_loss           | 50.5         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 292         |
# |    iterations           | 19          |
# |    time_elapsed         | 132         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.011475956 |
# |    clip_fraction        | 0.0971      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.4       |
# |    explained_variance   | 0.048       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 24.6        |
# |    n_updates            | 198         |
# |    policy_gradient_loss | -0.00902    |
# |    std                  | 1.02        |
# |    value_loss           | 52.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 290         |
# |    iterations           | 20          |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.012763248 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.4       |
# |    explained_variance   | 0.00304     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 26.9        |
# |    n_updates            | 208         |
# |    policy_gradient_loss | -0.00942    |
# |    std                  | 1.03        |
# |    value_loss           | 39.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 288         |
# |    iterations           | 21          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.010076417 |
# |    clip_fraction        | 0.0877      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.5       |
# |    explained_variance   | 0.0456      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 24.1        |
# |    n_updates            | 218         |
# |    policy_gradient_loss | -0.00996    |
# |    std                  | 1.03        |
# |    value_loss           | 43.6        |
# -----------------------------------------
# day: 1258, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 1796576.36
# total_reward: 796576.36
# total_cost: 80292.89
# total_trades: 11601
# Sharpe: 0.550
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 288          |
# |    iterations           | 22           |
# |    time_elapsed         | 156          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0104131475 |
# |    clip_fraction        | 0.106        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -14.5        |
# |    explained_variance   | 0.0112       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 34.1         |
# |    n_updates            | 228          |
# |    policy_gradient_loss | -0.00901     |
# |    std                  | 1.03         |
# |    value_loss           | 64.3         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 288         |
# |    iterations           | 23          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.009104935 |
# |    clip_fraction        | 0.0837      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.5       |
# |    explained_variance   | 0.0174      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 27          |
# |    n_updates            | 238         |
# |    policy_gradient_loss | -0.00641    |
# |    std                  | 1.03        |
# |    value_loss           | 69.3        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 287          |
# |    iterations           | 24           |
# |    time_elapsed         | 170          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0102324495 |
# |    clip_fraction        | 0.106        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -14.5        |
# |    explained_variance   | 0.0155       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 44.7         |
# |    n_updates            | 248          |
# |    policy_gradient_loss | -0.00746     |
# |    std                  | 1.03         |
# |    value_loss           | 87.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 287         |
# |    iterations           | 25          |
# |    time_elapsed         | 178         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.008617673 |
# |    clip_fraction        | 0.081       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.5       |
# |    explained_variance   | 0.0116      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 46.2        |
# |    n_updates            | 258         |
# |    policy_gradient_loss | -0.0101     |
# |    std                  | 1.03        |
# |    value_loss           | 126         |
# -----------------------------------------

# %%
trained_ppo.save("models/ppo")
# Out:
# C:\Users\Mateusz\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\stable_baselines3\common\save_util.py:284: UserWarning: Path 'models' does not exist. Will create it.
#   warnings.warn(f"Path '{path.parent}' does not exist. Will create it.")
