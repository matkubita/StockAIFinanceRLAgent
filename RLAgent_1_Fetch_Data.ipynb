# %%
import pandas as pd
import yfinance as yf

from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl import config_tickers
from finrl.config import INDICATORS
from finrl.config import *
import itertools
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 5
#       2 import yfinance as yf
#       4 from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
# ----> 5 from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
#       6 from finrl import config_tickers
#       7 from finrl.config import INDICATORS
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\finrl\meta\preprocessor\preprocessors.py:10
#       7 import pandas as pd
#       8 from stockstats import StockDataFrame as Sdf
# ---> 10 from finrl import config
#      11 from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
#      14 def load_dataset(*, file_name: str) -> pd.DataFrame:
#
# ...

# %%
TRAIN_START_DATE = '2018-01-01'
TRAIN_END_DATE = '2023-01-01'
TRADE_START_DATE = '2023-01-01'
TRADE_END_DATE = '2024-01-01'

# %%
tickers = ['AAPL', 'MSFT', 'NVDA', 'AMZN', 'GOOGL', 'META', 'TSLA', 'BRK-B', 'WMT', 'JPM']

# %%
df_raw = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TRADE_END_DATE,
                     ticker_list = tickers).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# [*********************100%***********************]  1 of 1 completed/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# ...

# %%
df_raw.head()
# Out:
# Price        date       close        high         low        open     volume  \
# 0      2018-01-02   40.341892   40.351262   39.639317   39.850091  102223600
# 1      2018-01-02   59.450500   59.500000   58.525501   58.599998   53890000
# 2      2018-01-02  197.220001  198.869995  195.960007  198.869995    4113000
# 3      2018-01-02   53.258095   53.395556   52.256167   52.256167   31766000
# 4      2018-01-02   86.730354   86.786594   85.814444   86.473257   13578800
#
# Price    tic  day
# 0       AAPL    1
# 1       AMZN    1
# 2      BRK-B    1
# 3      GOOGL    1
# 4        JPM    1
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# # Preprocess Data

# %%
fe = FeatureEngineer(use_technical_indicator=True,
                     tech_indicator_list = INDICATORS,
                     use_vix=True,
                     use_turbulence=True,
                     user_defined_feature = False)

processed = fe.preprocess_data(df_raw)
# Out:
# Successfully added technical indicators
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# [*********************100%***********************]  1 of 1 completed/usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#
# ...

# %%
list_ticker = processed["tic"].unique().tolist()
list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str))
combination = list(itertools.product(list_date,list_ticker))

processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")
processed_full = processed_full[processed_full['date'].isin(processed['date'])]
processed_full = processed_full.sort_values(['date','tic'])

processed_full = processed_full.fillna(0)
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
processed_full.head()
# Out:
#          date    tic       close        high         low        open  \
# 0  2018-01-02   AAPL   40.341892   40.351262   39.639317   39.850091
# 1  2018-01-02   AMZN   59.450500   59.500000   58.525501   58.599998
# 2  2018-01-02  BRK-B  197.220001  198.869995  195.960007  198.869995
# 3  2018-01-02  GOOGL   53.258095   53.395556   52.256167   52.256167
# 4  2018-01-02    JPM   86.730354   86.786594   85.814444   86.473257
#
#         volume  day  macd    boll_ub    boll_lb  rsi_30     cci_30  dx_30  \
# 0  102223600.0  1.0   0.0  40.348316  40.328442     0.0  66.666667  100.0
# 1   53890000.0  1.0   0.0  40.348316  40.328442     0.0  66.666667  100.0
# 2    4113000.0  1.0   0.0  40.348316  40.328442     0.0  66.666667  100.0
# 3   31766000.0  1.0   0.0  40.348316  40.328442     0.0  66.666667  100.0
# 4   13578800.0  1.0   0.0  40.348316  40.328442     0.0  66.666667  100.0
#
#    close_30_sma  close_60_sma   vix  turbulence
# 0     40.341892     40.341892  9.77         0.0
# ...

# %% [markdown]
# ## Save the Data

# %%
train = data_split(processed_full, TRAIN_START_DATE,TRAIN_END_DATE)
trade = data_split(processed_full, TRADE_START_DATE,TRADE_END_DATE)
print(len(train))
print(len(trade))
# Out:
# 12590
# 2490
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
from google.colab import drive
drive.mount('/content/drive')

import os


project_path = '/content/drive/MyDrive/ZMUM_FinRL'
if not os.path.exists(project_path):
    os.makedirs(project_path)


train.to_csv(f'{project_path}/train_data.csv', index=False)
trade.to_csv(f'{project_path}/trade_data.csv', index=False)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
